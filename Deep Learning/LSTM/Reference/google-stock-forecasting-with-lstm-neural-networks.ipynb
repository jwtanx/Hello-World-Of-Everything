# %% [markdown]
# ![GOOGLE](https://i.insider.com/59524dbdd084cc28008b5b4d?width=1000&format=jpeg&auto=webp)

# %% [markdown]
# # Author: Muhammad Bilal Hussain
# ## Topic: Google Stock Forecasting with LSTM Neural Networks
#
# [![Facebook](https://img.shields.io/badge/Facebook-%231877F2.svg?&style=for-the-badge&logo=Facebook&logoColor=white)](https://www.facebook.com/Bilalwsr)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-%230077B5.svg?&style=for-the-badge&logo=LinkedIn&logoColor=white)](https://www.linkedin.com/in/bilalwsr)
# [![Github](https://img.shields.io/badge/Github-%23121011.svg?&style=for-the-badge&logo=Github&logoColor=white)](https://github.com/bilalwsr)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('/kaggle/input/google-stocks-complete/GOOGLE.csv')
df
# Out:
#             Date        Open        High         Low       Close     Volume
# 0     2004-08-19    2.502503    2.604104    2.401401    2.511011  893181924
# 1     2004-08-20    2.527778    2.729730    2.515015    2.710460  456686856
# 2     2004-08-23    2.771522    2.839840    2.728979    2.737738  365122512
# 3     2004-08-24    2.783784    2.792793    2.591842    2.624374  304946748
# 4     2004-08-25    2.626627    2.702703    2.599600    2.652653  183772044
# ...          ...         ...         ...         ...         ...        ...
# 4712  2023-05-09  108.389999  110.150002  107.190002  107.349998   36360100
# 4713  2023-05-10  107.970001  112.940002  107.930000  111.750000   63153400
# 4714  2023-05-11  115.400002  117.919998  114.410004  116.570000   78900000
# 4715  2023-05-12  116.680000  118.029999  116.110001  117.510002   41073800
# 4716  2023-05-15  116.110001  118.480003  116.010002  116.510002   36226100
#
# [4717 rows x 6 columns]

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close     Volume
# 0  2004-08-19  2.502503  2.604104  2.401401  2.511011  893181924
# 1  2004-08-20  2.527778  2.729730  2.515015  2.710460  456686856
# 2  2004-08-23  2.771522  2.839840  2.728979  2.737738  365122512
# 3  2004-08-24  2.783784  2.792793  2.591842  2.624374  304946748
# 4  2004-08-25  2.626627  2.702703  2.599600  2.652653  183772044

# %% [markdown]
# # we are going to need only two columns for this

# %%
df = df[['Date', "Close"]]

# %%
df.head()
# Out:
#          Date     Close
# 0  2004-08-19  2.511011
# 1  2004-08-20  2.710460
# 2  2004-08-23  2.737738
# 3  2004-08-24  2.624374
# 4  2004-08-25  2.652653

# %%
df['Date']
# Out:
# 0       2004-08-19
# 1       2004-08-20
# 2       2004-08-23
# 3       2004-08-24
# 4       2004-08-25
#            ...
# 4712    2023-05-09
# 4713    2023-05-10
# 4714    2023-05-11
# 4715    2023-05-12
# 4716    2023-05-15
# Name: Date, Length: 4717, dtype: object

# %% [markdown]
# ## as we see  we have date as String(object) let's covert into actually date

# %%
# Lets convert
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)
datetime_object  = str_to_datetime('2004-08-25')
datetime_object
# Out:
# datetime.datetime(2004, 8, 25, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /tmp/ipykernel_20/2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      2004-08-19
# 1      2004-08-20
# 2      2004-08-23
# 3      2004-08-24
# 4      2004-08-25
#           ...
# 4712   2023-05-09
# 4713   2023-05-10
# 4714   2023-05-11
# 4715   2023-05-12
# 4716   2023-05-15
# Name: Date, Length: 4717, dtype: datetime64[ns]

# %%
# with command we will make date our index number 
df.index = df.pop('Date')

# %%
df.head()
# Out:
#                Close
# Date
# 2004-08-19  2.511011
# 2004-08-20  2.710460
# 2004-08-23  2.737738
# 2004-08-24  2.624374
# 2004-08-25  2.652653

# %%
df.plot();

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  101.534500  102.066498  101.626503  101.623001
# 1    2021-03-26  102.066498  101.626503  101.623001  101.236504
# 2    2021-03-29  101.626503  101.623001  101.236504  102.289497
# 3    2021-03-30  101.623001  101.236504  102.289497  102.323502
# 4    2021-03-31  101.236504  102.289497  102.323502  103.125999
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  125.950996  129.197998  133.280502  133.839005
# 248  2022-03-18  129.197998  133.280502  133.839005  136.125504
# 249  2022-03-21  133.280502  133.839005  136.125504  136.101501
# 250  2022-03-22  133.839005  136.125504  136.101501  139.867996
# 251  2022-03-23  136.125504  136.101501  139.867996  138.275497
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test']);

# %%
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100);
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 107ms/step - loss: 17465.4551 - mean_absolute_error: 131.5096 - val_loss: 18575.3965 - val_mean_absolute_error: 136.2005
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17380.0469 - mean_absolute_error: 131.1851 - val_loss: 18485.7832 - val_mean_absolute_error: 135.8711
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17291.7695 - mean_absolute_error: 130.8482 - val_loss: 18387.1406 - val_mean_absolute_error: 135.5075
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 17183.7109 - mean_absolute_error: 130.4342 - val_loss: 18243.2734 - val_mean_absolute_error: 134.9756
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17014.9375 - mean_absolute_error: 129.7862 - val_loss: 18016.6055 - val_mean_absolute_error: 134.1333
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 16765.3262 - mean_absolute_error: 128.8174 - val_loss: 17698.8945 - val_mean_absolute_error: 132.9435
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 16408.2754 - mean_absolute_error: 127.4213 - val_loss: 17230.4395 - val_mean_absolute_error: 131.1694
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 15871.2217 - mean_absolute_error: 125.2986 - val_loss: 16536.2207 - val_mean_absolute_error: 128.4954
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 15094.1016 - mean_absolute_error: 122.1291 - val_loss: 15507.7910 - val_mean_absolute_error: 124.4284
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 13965.3877 - mean_absolute_error: 117.4285 - val_loss: 14169.4990 - val_mean_absolute_error: 118.9299
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 12663.7227 - mean_absolute_error: 111.7417 - val_loss: 12756.1016 - val_mean_absolute_error: 112.8313
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 11252.0537 - mean_absolute_error: 105.2379 - val_loss: 11161.5664 - val_mean_absolute_error: 105.5267
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9563.4893 - mean_absolute_error: 96.8901 - val_loss: 9120.0820 - val_mean_absolute_error: 95.3635
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7562.9204 - mean_absolute_error: 85.9287 - val_loss: 7021.8979 - val_mean_absolute_error: 83.6449
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5657.1929 - mean_absolute_error: 74.0223 - val_loss: 5119.4751 - val_mean_absolute_error: 71.3754
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3991.7576 - mean_absolute_error: 61.7645 - val_loss: 3485.0791 - val_mean_absolute_error: 58.8199
# Epoch 17/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2556.4089 - mean_absolute_error: 48.7492 - val_loss: 2078.4026 - val_mean_absolute_error: 45.3126
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1437.3114 - mean_absolute_error: 35.4912 - val_loss: 1082.5470 - val_mean_absolute_error: 32.5152
# Epoch 19/100
# 7/7 [==============================] - 0s 10ms/step - loss: 688.0867 - mean_absolute_error: 23.0144 - val_loss: 405.6956 - val_mean_absolute_error: 19.5028
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 295.6958 - mean_absolute_error: 14.7747 - val_loss: 104.6897 - val_mean_absolute_error: 8.9648
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 185.1906 - mean_absolute_error: 12.1555 - val_loss: 31.1989 - val_mean_absolute_error: 4.6327
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 184.0923 - mean_absolute_error: 11.3450 - val_loss: 25.4024 - val_mean_absolute_error: 4.1446
# Epoch 23/100
# 7/7 [==============================] - 0s 9ms/step - loss: 187.9560 - mean_absolute_error: 11.2084 - val_loss: 26.1043 - val_mean_absolute_error: 4.1884
# Epoch 24/100
# 7/7 [==============================] - 0s 10ms/step - loss: 180.3954 - mean_absolute_error: 11.2524 - val_loss: 31.6408 - val_mean_absolute_error: 4.6695
# Epoch 25/100
# 7/7 [==============================] - 0s 12ms/step - loss: 171.6048 - mean_absolute_error: 11.4132 - val_loss: 42.7949 - val_mean_absolute_error: 5.5232
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 168.9733 - mean_absolute_error: 11.6497 - val_loss: 52.0120 - val_mean_absolute_error: 6.1055
# Epoch 27/100
# 7/7 [==============================] - 0s 10ms/step - loss: 166.8460 - mean_absolute_error: 11.6642 - val_loss: 54.2019 - val_mean_absolute_error: 6.2142
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 158.1709 - mean_absolute_error: 11.4649 - val_loss: 57.5862 - val_mean_absolute_error: 6.3971
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 152.4315 - mean_absolute_error: 11.2068 - val_loss: 53.2999 - val_mean_absolute_error: 6.1422
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 151.5721 - mean_absolute_error: 11.2446 - val_loss: 47.6644 - val_mean_absolute_error: 5.8146
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 148.7195 - mean_absolute_error: 10.8768 - val_loss: 38.0873 - val_mean_absolute_error: 5.1765
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 142.0828 - mean_absolute_error: 10.8008 - val_loss: 57.5990 - val_mean_absolute_error: 6.3952
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 137.7473 - mean_absolute_error: 10.6295 - val_loss: 33.9614 - val_mean_absolute_error: 4.8464
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 134.1005 - mean_absolute_error: 10.3134 - val_loss: 43.4130 - val_mean_absolute_error: 5.5248
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 131.5157 - mean_absolute_error: 10.2663 - val_loss: 35.9192 - val_mean_absolute_error: 5.0055
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 128.5044 - mean_absolute_error: 10.2152 - val_loss: 40.4586 - val_mean_absolute_error: 5.3164
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 119.6765 - mean_absolute_error: 9.8253 - val_loss: 39.9068 - val_mean_absolute_error: 5.2685
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 112.2027 - mean_absolute_error: 9.5637 - val_loss: 39.3254 - val_mean_absolute_error: 5.2049
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 102.7240 - mean_absolute_error: 9.1777 - val_loss: 35.4968 - val_mean_absolute_error: 4.9104
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 87.2782 - mean_absolute_error: 8.4574 - val_loss: 26.6817 - val_mean_absolute_error: 4.1770
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 71.9836 - mean_absolute_error: 7.6449 - val_loss: 34.8690 - val_mean_absolute_error: 4.8764
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 59.8169 - mean_absolute_error: 6.9108 - val_loss: 26.9219 - val_mean_absolute_error: 4.1578
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 46.1166 - mean_absolute_error: 6.0816 - val_loss: 22.1566 - val_mean_absolute_error: 3.7057
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 35.1387 - mean_absolute_error: 5.2612 - val_loss: 21.0744 - val_mean_absolute_error: 3.5995
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 28.9656 - mean_absolute_error: 4.6620 - val_loss: 16.7650 - val_mean_absolute_error: 3.1222
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 22.2788 - mean_absolute_error: 3.9913 - val_loss: 10.6403 - val_mean_absolute_error: 2.4332
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 17.0880 - mean_absolute_error: 3.4360 - val_loss: 11.5179 - val_mean_absolute_error: 2.5091
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 13.0141 - mean_absolute_error: 2.9625 - val_loss: 9.7560 - val_mean_absolute_error: 2.3191
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 8.6093 - mean_absolute_error: 2.4134 - val_loss: 9.5762 - val_mean_absolute_error: 2.2705
# Epoch 50/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.3370 - mean_absolute_error: 2.0329 - val_loss: 10.1097 - val_mean_absolute_error: 2.3428
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.4105 - mean_absolute_error: 1.8727 - val_loss: 9.4428 - val_mean_absolute_error: 2.2634
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6676 - mean_absolute_error: 1.7070 - val_loss: 9.7861 - val_mean_absolute_error: 2.3198
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.3190 - mean_absolute_error: 1.6421 - val_loss: 9.7567 - val_mean_absolute_error: 2.3224
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.2470 - mean_absolute_error: 1.6214 - val_loss: 11.2471 - val_mean_absolute_error: 2.4873
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6436 - mean_absolute_error: 1.7132 - val_loss: 12.8065 - val_mean_absolute_error: 2.7463
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8037 - mean_absolute_error: 1.7158 - val_loss: 12.1275 - val_mean_absolute_error: 2.6393
# Epoch 57/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.5436 - mean_absolute_error: 1.6559 - val_loss: 10.8261 - val_mean_absolute_error: 2.4406
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8082 - mean_absolute_error: 1.5128 - val_loss: 10.1839 - val_mean_absolute_error: 2.3815
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8709 - mean_absolute_error: 1.5371 - val_loss: 10.0811 - val_mean_absolute_error: 2.3695
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.1760 - mean_absolute_error: 1.5950 - val_loss: 9.6467 - val_mean_absolute_error: 2.3174
# Epoch 61/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.1321 - mean_absolute_error: 1.6035 - val_loss: 9.7775 - val_mean_absolute_error: 2.3320
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6822 - mean_absolute_error: 1.6922 - val_loss: 9.9004 - val_mean_absolute_error: 2.3720
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.4573 - mean_absolute_error: 1.6945 - val_loss: 9.7216 - val_mean_absolute_error: 2.3254
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.1907 - mean_absolute_error: 1.5923 - val_loss: 10.0389 - val_mean_absolute_error: 2.3615
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6887 - mean_absolute_error: 1.7514 - val_loss: 12.9610 - val_mean_absolute_error: 2.7729
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9293 - mean_absolute_error: 1.5766 - val_loss: 11.3706 - val_mean_absolute_error: 2.5327
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.8332 - mean_absolute_error: 1.5326 - val_loss: 10.8851 - val_mean_absolute_error: 2.4796
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3.7011 - mean_absolute_error: 1.4614 - val_loss: 10.9181 - val_mean_absolute_error: 2.4863
# Epoch 69/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.6403 - mean_absolute_error: 1.4738 - val_loss: 9.7974 - val_mean_absolute_error: 2.3373
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7806 - mean_absolute_error: 1.5197 - val_loss: 9.8257 - val_mean_absolute_error: 2.3390
# Epoch 71/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0768 - mean_absolute_error: 1.5767 - val_loss: 12.1446 - val_mean_absolute_error: 2.6517
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0195 - mean_absolute_error: 1.5549 - val_loss: 13.8926 - val_mean_absolute_error: 2.9167
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.4155 - mean_absolute_error: 1.6286 - val_loss: 13.0735 - val_mean_absolute_error: 2.7852
# Epoch 74/100
# 7/7 [==============================] - 0s 12ms/step - loss: 4.4281 - mean_absolute_error: 1.6986 - val_loss: 9.8952 - val_mean_absolute_error: 2.3547
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.8364 - mean_absolute_error: 1.5057 - val_loss: 10.0293 - val_mean_absolute_error: 2.4075
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0064 - mean_absolute_error: 1.5836 - val_loss: 9.8821 - val_mean_absolute_error: 2.3535
# Epoch 77/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.4900 - mean_absolute_error: 1.4381 - val_loss: 10.7308 - val_mean_absolute_error: 2.4682
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2770 - mean_absolute_error: 1.3801 - val_loss: 10.0247 - val_mean_absolute_error: 2.3632
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3465 - mean_absolute_error: 1.4093 - val_loss: 9.9032 - val_mean_absolute_error: 2.3547
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2123 - mean_absolute_error: 1.6061 - val_loss: 10.0128 - val_mean_absolute_error: 2.3658
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3679 - mean_absolute_error: 1.4180 - val_loss: 11.2068 - val_mean_absolute_error: 2.5319
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6225 - mean_absolute_error: 1.4758 - val_loss: 10.6524 - val_mean_absolute_error: 2.4592
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.5850 - mean_absolute_error: 1.4582 - val_loss: 10.2584 - val_mean_absolute_error: 2.3892
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3847 - mean_absolute_error: 1.4045 - val_loss: 10.0624 - val_mean_absolute_error: 2.3711
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7705 - mean_absolute_error: 1.4823 - val_loss: 10.9150 - val_mean_absolute_error: 2.4974
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8444 - mean_absolute_error: 1.5101 - val_loss: 10.2116 - val_mean_absolute_error: 2.3820
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2874 - mean_absolute_error: 1.3966 - val_loss: 10.0786 - val_mean_absolute_error: 2.3748
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5005 - mean_absolute_error: 1.4645 - val_loss: 10.8449 - val_mean_absolute_error: 2.4871
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4722 - mean_absolute_error: 1.3969 - val_loss: 11.7950 - val_mean_absolute_error: 2.6205
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2708 - mean_absolute_error: 1.3964 - val_loss: 11.4982 - val_mean_absolute_error: 2.5735
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4682 - mean_absolute_error: 1.4415 - val_loss: 9.9809 - val_mean_absolute_error: 2.3722
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5058 - mean_absolute_error: 1.4533 - val_loss: 10.0573 - val_mean_absolute_error: 2.3745
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3657 - mean_absolute_error: 1.4045 - val_loss: 10.2615 - val_mean_absolute_error: 2.3919
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0330 - mean_absolute_error: 1.5868 - val_loss: 14.4424 - val_mean_absolute_error: 2.9953
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8869 - mean_absolute_error: 1.7384 - val_loss: 15.6151 - val_mean_absolute_error: 3.2045
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0088 - mean_absolute_error: 1.6249 - val_loss: 10.7790 - val_mean_absolute_error: 2.5505
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.8721 - mean_absolute_error: 1.5533 - val_loss: 10.2524 - val_mean_absolute_error: 2.3931
# Epoch 98/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7313 - mean_absolute_error: 1.5315 - val_loss: 11.0566 - val_mean_absolute_error: 2.5175
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2810 - mean_absolute_error: 1.3987 - val_loss: 11.3925 - val_mean_absolute_error: 2.5602
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.4197 - mean_absolute_error: 1.4253 - val_loss: 10.8166 - val_mean_absolute_error: 2.4810

# %%
train_predictions = model.predict(X_train).flatten()

fig = plt.figure(figsize=(10, 6))

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations']);
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

fig = plt.figure(figsize=(12, 6))
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations']);
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
test_predictions = model.predict(X_test).flatten()
fig = plt.figure(figsize=(12, 6))
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations']);
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
fig = plt.figure(figsize=(10, 6))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations']);

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
fig = plt.figure(figsize=(10, 6))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions']);

# %% [markdown]
# ## Conclusion:
# ### There are other factors involved in the prediction, such as physical and psychological factors, rational and irrational behavior, and so on. All these factors combine to make share prices dynamic and volatile. This makes it very difficult to predict stock prices with high accuracy.
